# %% [markdown]
# <a href="https://colab.research.google.com/github/chifie/machine-learning-journey/blob/main/simple_vector_addition_using_tension_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import TensorFlow
import tensorflow as tf

# Create two vectors
vector1 = tf.constant([1, 2, 3])
vector2 = tf.constant([4, 5, 6])

# Perform vector addition
result = tf.add(vector1, vector2)

# Display the results
print("Vector 1:", vector1.numpy())
print("Vector 2:", vector2.numpy())
print("Vector Addition:", result.numpy())
# Out:
# Vector 1: [1 2 3]
# Vector 2: [4 5 6]
# Vector Addition: [5 7 9]
